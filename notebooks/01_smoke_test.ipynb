# %%
import pandas as pd


df = pd.read_csv("../data/sample.csv")

print("Shape:", df.shape)

print("First 5 rows:")
print(df.head())

print("Statistical Summary:")
print(df.describe())
# Out:
# Shape: (5, 3)
# First 5 rows:
#       name  score  passed
# 0    Alice     85    True
# 1      Bob     72    True
# 2  Carolen     79   False
# 3    Diana     41   False
# 4    Diala     79    True
# Statistical Summary:
#            score
# count   5.000000
# mean   71.200000
# std    17.498571
# min    41.000000
# 25%    72.000000
# 50%    79.000000
# 75%    79.000000
# max    85.000000
